# %%
import pandas as pd
df    = pd.read_csv('/kaggle/input/glassdoor-job-reviews/glassdoor_reviews.csv', sep=',', encoding='latin-1')
print("All columns : ");
print(df.columns);
Notkeep = [d for d in df.columns if d not in ['firm', 'date_review', 'job_title','work_life_balance', 'culture_values',
       'diversity_inclusion', 'career_opp', 'comp_benefits', 'senior_mgmt','recommend', 'ceo_approv', 'outlook']]
print("\nRemoved columns : ");
print(Notkeep);
data    = df.drop(columns=Notkeep)
print("\nSelected columns : ");
print(data.columns);
data['year'] = pd.DatetimeIndex(data['date_review']).year
data = data.drop(columns=['date_review'])
# Out:
# All columns :
# Index(['firm', 'date_review', 'job_title', 'current', 'location',
#        'overall_rating', 'work_life_balance', 'culture_values',
#        'diversity_inclusion', 'career_opp', 'comp_benefits', 'senior_mgmt',
#        'recommend', 'ceo_approv', 'outlook', 'headline', 'pros', 'cons'],
#       dtype='object')
#
# Removed columns :
# ['current', 'location', 'overall_rating', 'headline', 'pros', 'cons']
#
# Selected columns :
# Index(['firm', 'date_review', 'job_title', 'work_life_balance',
#        'culture_values', 'diversity_inclusion', 'career_opp', 'comp_benefits',
#        'senior_mgmt', 'recommend', 'ceo_approv', 'outlook'],
#       dtype='object')

# %%
data
# Out:
#                          firm                         job_title  \
# 0       AFH-Wealth-Management
# 1       AFH-Wealth-Management              Office Administrator
# 2       AFH-Wealth-Management              Office Administrator
# 3       AFH-Wealth-Management
# 4       AFH-Wealth-Management              Office Administrator
# ...                       ...                               ...
# 838561         the-LEGO-Group                 Marketing Manager
# 838562         the-LEGO-Group                   Sales Associate
# 838563         the-LEGO-Group                        Strategist
# 838564         the-LEGO-Group   Customer Service Representative
# 838565         the-LEGO-Group        Human Resources Specialist
#
#         work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 0                     4.0             3.0                  NaN         2.0
# 1                     3.0             1.0                  NaN         2.0
# ...

# %%
Notkeep_2 = [d for d in df.columns if d not in ['firm', 'date_review', 'job_title','work_life_balance', 'culture_values',
       'diversity_inclusion', 'career_opp', 'comp_benefits', 'senior_mgmt','recommend', 'ceo_approv', 'outlook', 'headline', 'pros', 'cons']]
print("\nRemoved columns : ");
print(Notkeep_2);
data_2    = df.drop(columns=Notkeep_2)
print("\nSelected columns : ");
print(data_2.columns);
data_2['year'] = pd.DatetimeIndex(data_2['date_review']).year
data_2 = data_2.drop(columns=['date_review'])
# Out:
# Removed columns :
# ['current', 'location', 'overall_rating']
#
# Selected columns :
# Index(['firm', 'date_review', 'job_title', 'work_life_balance',
#        'culture_values', 'diversity_inclusion', 'career_opp', 'comp_benefits',
#        'senior_mgmt', 'recommend', 'ceo_approv', 'outlook', 'headline', 'pros',
#        'cons'],
#       dtype='object')

# %%
data_2
# Out:
#                          firm                         job_title  \
# 0       AFH-Wealth-Management
# 1       AFH-Wealth-Management              Office Administrator
# 2       AFH-Wealth-Management              Office Administrator
# 3       AFH-Wealth-Management
# 4       AFH-Wealth-Management              Office Administrator
# ...                       ...                               ...
# 838561         the-LEGO-Group                 Marketing Manager
# 838562         the-LEGO-Group                   Sales Associate
# 838563         the-LEGO-Group                        Strategist
# 838564         the-LEGO-Group   Customer Service Representative
# 838565         the-LEGO-Group        Human Resources Specialist
#
#         work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 0                     4.0             3.0                  NaN         2.0
# 1                     3.0             1.0                  NaN         2.0
# ...

# %%
import missingno as msno
msno.matrix(data,color=(0.3,0.36,0.44));

# %%
data.isna().sum()
# Out:
# firm                        0
# job_title                   0
# work_life_balance      149894
# culture_values         191373
# diversity_inclusion    702500
# career_opp             147501
# comp_benefits          150082
# senior_mgmt            155876
# recommend                   0
# ceo_approv                  0
# outlook                     0
# year                        0
# dtype: int64

# %%
msno.matrix(data_2,color=(0.3,0.36,0.44));

# %%
data_2.isna().sum()
# Out:
# firm                        0
# job_title                   0
# work_life_balance      149894
# culture_values         191373
# diversity_inclusion    702500
# career_opp             147501
# comp_benefits          150082
# senior_mgmt            155876
# recommend                   0
# ceo_approv                  0
# outlook                     0
# headline                 2590
# pros                        2
# cons                       13
# year                        0
# dtype: int64

# %%
import pandas as pd

data['work_life_balance'] = data['work_life_balance'].fillna(0)
data['culture_values'] = data['culture_values'].fillna(0)             
data['diversity_inclusion'] = data['diversity_inclusion'].fillna(0)                 
data['career_opp'] = data['career_opp'].fillna(0)                 
data['comp_benefits'] = data['comp_benefits'].fillna(0)
data['senior_mgmt'] = data['senior_mgmt'].fillna(0)

# %%
data_2['work_life_balance'] = data_2['work_life_balance'].fillna(0)
data_2['culture_values'] = data_2['culture_values'].fillna(0)             
data_2['diversity_inclusion'] = data_2['diversity_inclusion'].fillna(0)                 
data_2['career_opp'] = data_2['career_opp'].fillna(0)                 
data_2['comp_benefits'] = data_2['comp_benefits'].fillna(0)
data_2['senior_mgmt'] = data_2['senior_mgmt'].fillna(0)

# %%
msno.matrix(data,color=(0.3,0.36,0.44));

# %%
msno.matrix(data_2,color=(0.3,0.36,0.44));

# %%
data.isna().sum()
# Out:
# firm                   0
# job_title              0
# work_life_balance      0
# culture_values         0
# diversity_inclusion    0
# career_opp             0
# comp_benefits          0
# senior_mgmt            0
# recommend              0
# ceo_approv             0
# outlook                0
# year                   0
# dtype: int64

# %%
data_2.isna().sum()
# Out:
# firm                      0
# job_title                 0
# work_life_balance         0
# culture_values            0
# diversity_inclusion       0
# career_opp                0
# comp_benefits             0
# senior_mgmt               0
# recommend                 0
# ceo_approv                0
# outlook                   0
# headline               2590
# pros                      2
# cons                     13
# year                      0
# dtype: int64

# %%
replacement_dict = {'v': 5, 'r': 3, 'o': 1, 'x': 0}

data['recommend'] = data['recommend'].replace(replacement_dict)
data['ceo_approv'] = data['ceo_approv'].replace(replacement_dict)
data['outlook'] = data['outlook'].replace(replacement_dict)

data
# Out:
#                          firm                         job_title  \
# 0       AFH-Wealth-Management
# 1       AFH-Wealth-Management              Office Administrator
# 2       AFH-Wealth-Management              Office Administrator
# 3       AFH-Wealth-Management
# 4       AFH-Wealth-Management              Office Administrator
# ...                       ...                               ...
# 838561         the-LEGO-Group                 Marketing Manager
# 838562         the-LEGO-Group                   Sales Associate
# 838563         the-LEGO-Group                        Strategist
# 838564         the-LEGO-Group   Customer Service Representative
# 838565         the-LEGO-Group        Human Resources Specialist
#
#         work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 0                     4.0             3.0                  0.0         2.0
# 1                     3.0             1.0                  0.0         2.0
# ...

# %%
data_2['recommend'] = data_2['recommend'].replace(replacement_dict)
data_2['ceo_approv'] = data_2['ceo_approv'].replace(replacement_dict)
data_2['outlook'] = data_2['outlook'].replace(replacement_dict)

data_2
# Out:
#                          firm                         job_title  \
# 0       AFH-Wealth-Management
# 1       AFH-Wealth-Management              Office Administrator
# 2       AFH-Wealth-Management              Office Administrator
# 3       AFH-Wealth-Management
# 4       AFH-Wealth-Management              Office Administrator
# ...                       ...                               ...
# 838561         the-LEGO-Group                 Marketing Manager
# 838562         the-LEGO-Group                   Sales Associate
# 838563         the-LEGO-Group                        Strategist
# 838564         the-LEGO-Group   Customer Service Representative
# 838565         the-LEGO-Group        Human Resources Specialist
#
#         work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 0                     4.0             3.0                  0.0         2.0
# 1                     3.0             1.0                  0.0         2.0
# ...

# %%
unique_firms_count = len(data['firm'].unique())
print(unique_firms_count)
# Out:
# 428

# %%
data_2.to_csv('all_reviews.csv', index=False)

# %%
import pandas as pd

average_scores = data.groupby('firm').agg({
    'work_life_balance': 'mean',
    'culture_values': 'mean',
    'diversity_inclusion': 'mean',
    'career_opp': 'mean',
    'comp_benefits': 'mean',
    'senior_mgmt': 'mean',
    'recommend': 'mean',
    'ceo_approv': 'mean'
}).reset_index()

average_scores.to_csv('average_all_scores.csv', index=False)

print("Average scores saved to average_all_scores.csv")
# Out:
# Average scores saved to average_all_scores.csv

# %%
title_counts = data.groupby('firm')['job_title'].value_counts().reset_index(name='title_count')
year_counts = data.groupby('firm')['year'].value_counts().reset_index(name='year_count')

title_counts.to_csv('title_counts.csv', index=False)
year_counts.to_csv('year_counts.csv', index=False)

print("Title counts saved to title_counts.csv")
print("Year counts saved to year_counts.csv")
# Out:
# Title counts saved to title_counts.csv
# Year counts saved to year_counts.csv
